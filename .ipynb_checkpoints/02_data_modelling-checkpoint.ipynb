# %% [markdown]
# # Traffic Volume Prediction: Data Modelling
#
# This notebook loads cleaned data from `cleaned data/` (produced by `EDA_and_feature_engineering.ipynb`)
# and fits regression models to predict traffic volume using direct weather measurements and ERA5 climate data.
#
# Models used: Linear Regression, Decision Tree, Random Forest, Bagging, XGBoost.

# %% [markdown]
# # 1. Import Modules

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from xgboost import XGBRegressor

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # 2. Load Cleaned Data

# %%
traffic = pd.read_csv('cleaned data/traffic.csv', parse_dates=['date_time'])
ERA5 = pd.read_csv('cleaned data/ERA5.csv', parse_dates=['date_time'])

dummy_holiday = pd.read_csv('cleaned data/dummy_holiday.csv')
dummy_weaMain = pd.read_csv('cleaned data/dummy_weaMain.csv')
dummy_weaDesc = pd.read_csv('cleaned data/dummy_weaDesc.csv')
dummy_seasonalities = pd.read_csv('cleaned data/dummy_seasonalities.csv')

print('Loaded successfully.')
print(f'dummy_seasonalities shape: {dummy_seasonalities.shape}')  # Should be (N, 30)
traffic.head()
# Out:
# Loaded successfully.
# dummy_seasonalities shape: (48176, 30)
#             date_time  year  month  day  hour day_of_week holiday  \
# 0 2012-10-02 09:00:00  2012     10    2     9     Tuesday     NaN
# 1 2012-10-02 10:00:00  2012     10    2    10     Tuesday     NaN
# 2 2012-10-02 11:00:00  2012     10    2    11     Tuesday     NaN
# 3 2012-10-02 12:00:00  2012     10    2    12     Tuesday     NaN
# 4 2012-10-02 13:00:00  2012     10    2    13     Tuesday     NaN
#
#    traffic_volume    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0            5545  288.28      0.0      0.0          40       Clouds
# 1            4516  289.36      0.0      0.0          75       Clouds
# 2            4767  289.58      0.0      0.0          90       Clouds
# 3            5026  290.13      0.0      0.0          90       Clouds
# 4            4918  291.14      0.0      0.0          75       Clouds
#
#   weather_description weather_condition   is_holiday
# 0    scattered clouds      Good weather  Non-holiday
# 1       broken clouds      Good weather  Non-holiday
# 2     overcast clouds      Good weather  Non-holiday
# 3     overcast clouds      Good weather  Non-holiday
# 4       broken clouds      Good weather  Non-holiday

# %% [markdown]
# # 3. Shared Setup
#
# "Bad weather" is defined as any row where `weather_main` is not 'Clear' or 'Clouds'.

# %%
# Array for "bad weather" (NOT "Clear" AND NOT "Clouds") booleans in array
bad_weather = (traffic.weather_main != 'Clear') & (traffic.weather_main != 'Clouds')

bad_weather.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: weather_main, dtype: bool

# %% [markdown]
# ## Model List
#
#
# The same five regression models are applied across all feature sets.
#
# Hyperparameters are tuned to reduce overfitting observed in initial results:
# - **Linear Regression**: No hyperparameters to tune; no overfitting observed.
# - **Decision Tree**: `max_depth=8`, `min_samples_split=40`, and `min_samples_leaf=20` limit tree complexity and reduce overfitting.
# - **Random Forest**: `max_depth=8`, `min_samples_split=40`, `min_samples_leaf=20`, and `max_features='sqrt'` improve generalisation while `n_estimators=100` provides stable ensemble performance.
# - **Bagging**: Uses constrained decision trees with `max_samples=0.5`, `max_features=0.5`, and `bootstrap_features=True` to increase diversity and reduce variance.
# - **XGBoost**: `max_depth=4`, `min_child_weight=50`, `subsample=0.5`, `colsample_bytree=0.5`, `reg_alpha=10.0`, `reg_lambda=10.0`, and `gamma=2.0` apply strong regularisation to minimise overfitting.

# %%
# List of models
models = {
    'Linear Regression': LinearRegression(),

    'Decision Tree': DecisionTreeRegressor(
        max_depth=8,
        min_samples_split=40,
        min_samples_leaf=20,
        random_state=42
    ),

    'Random Forest': RandomForestRegressor(
        n_estimators=100,
        max_depth=8,
        min_samples_split=40,
        min_samples_leaf=20,
        max_features='sqrt',
        bootstrap=True,
        random_state=42,
        n_jobs=-1
    ),

    'Bagging': BaggingRegressor(
        estimator=DecisionTreeRegressor(
            max_depth=8,
            min_samples_split=40,
            min_samples_leaf=20,
            random_state=42
        ),
        n_estimators=100,
        max_samples=0.5,
        max_features=0.5,
        bootstrap_features=True,
        random_state=42,
        n_jobs=-1
    ),
    
    'xGBoost': XGBRegressor(
        n_estimators=100,
        max_depth=4,
        min_child_weight=50,
        subsample=0.5,
        colsample_bytree=0.5,
        reg_alpha=10.0,
        reg_lambda=10.0,
        gamma=2.0,
        learning_rate=0.3,
        random_state=42,
        n_jobs=-1
    ),
}

# %% [markdown]
# # 4. Modelling on Traffic Weather Data
#
# From the EDA, we fit:
# - Qualitative: Hour of day, Day of the week, Month of year (all via harmonic sin/cos encoding, 30 columns), Holidays (11)
# - Quantitative: Temperature
#
# Rainfall, Snowfall, and Cloud coverage are not used due to redundancy with weather descriptions.
#
# The test set is the last 30% of rows (chronological split), to simulate future traffic prediction rather than interpolation.
#
# "Bad weather RMSE" is RMSE computed only on rows where `bad_weather` is True.
# ## 4.1 Build Feature Sets

# %%
# Dataframe for no weather conditions considered in model
X_none = pd.concat([traffic.temp, dummy_seasonalities, dummy_holiday],
                   axis=1)
y_none = traffic.traffic_volume

print(f'X_none shape: {X_none.shape}')
X_none.head()
# Out:
# X_none shape: (48176, 42)
#      temp    hour_sin_1  hour_cos_1    hour_sin_2    hour_cos_2    hour_sin_3  \
# 0  288.28  7.071068e-01   -0.707107 -1.000000e+00 -1.836970e-16  7.071068e-01
# 1  289.36  5.000000e-01   -0.866025 -8.660254e-01  5.000000e-01  1.000000e+00
# 2  289.58  2.588190e-01   -0.965926 -5.000000e-01  8.660254e-01  7.071068e-01
# 3  290.13  1.224647e-16   -1.000000 -2.449294e-16  1.000000e+00  3.673940e-16
# 4  291.14 -2.588190e-01   -0.965926  5.000000e-01  8.660254e-01 -7.071068e-01
#
#      hour_cos_3    hour_sin_4  hour_cos_4    hour_sin_5  ...  Columbus Day  \
# 0  7.071068e-01  3.673940e-16        -1.0 -7.071068e-01  ...         False
# 1  1.194340e-15 -8.660254e-01        -0.5  5.000000e-01  ...         False
# 2 -7.071068e-01 -8.660254e-01         0.5  9.659258e-01  ...         False
# 3 -1.000000e+00 -4.898587e-16         1.0  2.388680e-15  ...         False
# 4 -7.071068e-01  8.660254e-01         0.5 -9.659258e-01  ...         False
#
#    Independence Day  Labor Day  Martin Luther King Jr Day  Memorial Day  \
# 0             False      False                      False         False
# 1             False      False                      False         False
# 2             False      False                      False         False
# 3             False      False                      False         False
# 4             False      False                      False         False
#
#    New Years Day  State Fair  Thanksgiving Day  Veterans Day  \
# 0          False       False             False         False
# 1          False       False             False         False
# 2          False       False             False         False
# 3          False       False             False         False
# 4          False       False             False         False
#
#    Washingtons Birthday
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
#
# [5 rows x 42 columns]

# %%
# Dataframe for main weather conditions considered in model
X_main = pd.concat([traffic.temp, dummy_seasonalities, dummy_holiday, dummy_weaMain],
                   axis=1)
y_main = traffic.traffic_volume

print(f'X_main shape: {X_main.shape}')
X_main.head()
# Out:
# X_main shape: (48176, 53)
#      temp    hour_sin_1  hour_cos_1    hour_sin_2    hour_cos_2    hour_sin_3  \
# 0  288.28  7.071068e-01   -0.707107 -1.000000e+00 -1.836970e-16  7.071068e-01
# 1  289.36  5.000000e-01   -0.866025 -8.660254e-01  5.000000e-01  1.000000e+00
# 2  289.58  2.588190e-01   -0.965926 -5.000000e-01  8.660254e-01  7.071068e-01
# 3  290.13  1.224647e-16   -1.000000 -2.449294e-16  1.000000e+00  3.673940e-16
# 4  291.14 -2.588190e-01   -0.965926  5.000000e-01  8.660254e-01 -7.071068e-01
#
#      hour_cos_3    hour_sin_4  hour_cos_4    hour_sin_5  ...  Clouds  Drizzle  \
# 0  7.071068e-01  3.673940e-16        -1.0 -7.071068e-01  ...    True    False
# 1  1.194340e-15 -8.660254e-01        -0.5  5.000000e-01  ...    True    False
# 2 -7.071068e-01 -8.660254e-01         0.5  9.659258e-01  ...    True    False
# 3 -1.000000e+00 -4.898587e-16         1.0  2.388680e-15  ...    True    False
# 4 -7.071068e-01  8.660254e-01         0.5 -9.659258e-01  ...    True    False
#
#      Fog   Haze   Mist   Rain  Smoke   Snow  Squall  Thunderstorm
# 0  False  False  False  False  False  False   False         False
# 1  False  False  False  False  False  False   False         False
# 2  False  False  False  False  False  False   False         False
# 3  False  False  False  False  False  False   False         False
# 4  False  False  False  False  False  False   False         False
#
# [5 rows x 53 columns]

# %%
# Dataframe for detailed weather descriptions considered in model
X_desc = pd.concat([traffic.temp, dummy_seasonalities, dummy_holiday, dummy_weaDesc],
                   axis=1)
y_desc = traffic.traffic_volume

print(f'X_desc shape: {X_desc.shape}')
X_desc.head()
# Out:
# X_desc shape: (48176, 79)
#      temp    hour_sin_1  hour_cos_1    hour_sin_2    hour_cos_2    hour_sin_3  \
# 0  288.28  7.071068e-01   -0.707107 -1.000000e+00 -1.836970e-16  7.071068e-01
# 1  289.36  5.000000e-01   -0.866025 -8.660254e-01  5.000000e-01  1.000000e+00
# 2  289.58  2.588190e-01   -0.965926 -5.000000e-01  8.660254e-01  7.071068e-01
# 3  290.13  1.224647e-16   -1.000000 -2.449294e-16  1.000000e+00  3.673940e-16
# 4  291.14 -2.588190e-01   -0.965926  5.000000e-01  8.660254e-01 -7.071068e-01
#
#      hour_cos_3    hour_sin_4  hour_cos_4    hour_sin_5  ...  sleet  smoke  \
# 0  7.071068e-01  3.673940e-16        -1.0 -7.071068e-01  ...  False  False
# 1  1.194340e-15 -8.660254e-01        -0.5  5.000000e-01  ...  False  False
# 2 -7.071068e-01 -8.660254e-01         0.5  9.659258e-01  ...  False  False
# 3 -1.000000e+00 -4.898587e-16         1.0  2.388680e-15  ...  False  False
# 4 -7.071068e-01  8.660254e-01         0.5 -9.659258e-01  ...  False  False
#
#     snow  thunderstorm  thunderstorm with drizzle  \
# 0  False         False                      False
# 1  False         False                      False
# 2  False         False                      False
# 3  False         False                      False
# 4  False         False                      False
#
#    thunderstorm with heavy rain  thunderstorm with light drizzle  \
# 0                         False                            False
# 1                         False                            False
# 2                         False                            False
# 3                         False                            False
# 4                         False                            False
#
#    thunderstorm with light rain  thunderstorm with rain  very heavy rain
# 0                         False                   False            False
# 1                         False                   False            False
# 2                         False                   False            False
# 3                         False                   False            False
# 4                         False                   False            False
#
# [5 rows x 79 columns]

# %% [markdown]
# ## 4.2 Apply Models (No Weather)

# %%
# Empty lists
model_used = []
r2 = []
RMSE_train = []
RMSE_test = []
RMSE_bad_weather = []

# Saved predictions for scatter plots (keyed by model name)
none_preds = {}

# Split into training and test data
rows = int(len(X_none.index) * 3/10)

X_train_none = X_none[:-rows]
X_test_none  = X_none[-rows:]

y_train_none = y_none[:-rows]
y_test_none  = y_none[-rows:]

bad_weather_test = bad_weather[-rows:]

# Evaluate models
for name, model in models.items():
    model.fit(X_train_none, y_train_none)
    y_train_pred = model.predict(X_train_none)
    y_test_pred  = model.predict(X_test_none)

    model_r2            = r2_score(y_test_none, y_test_pred)
    model_rmse_train    = np.sqrt(mean_squared_error(y_train_none, y_train_pred))
    model_rmse_test     = np.sqrt(mean_squared_error(y_test_none, y_test_pred))

    y_bad_weather      = y_test_none[bad_weather_test]
    y_bad_weather_pred = y_test_pred[bad_weather_test]
    model_rmse_bad_weather = np.sqrt(mean_squared_error(y_bad_weather, y_bad_weather_pred))

    # Save predictions
    none_preds[name] = {
        'y_train':      y_train_none,
        'y_train_pred': y_train_pred,
        'y_test':       y_test_none,
        'y_test_pred':  y_test_pred,
        'y_bad_weather':      y_bad_weather,
        'y_bad_weather_pred': y_bad_weather_pred,
    }

    model_used.append(name)
    r2.append(model_r2)
    RMSE_train.append(model_rmse_train)
    RMSE_test.append(model_rmse_test)
    RMSE_bad_weather.append(model_rmse_bad_weather)

    print(f'--------- Results for model: {name} ---------')
    print(f'Test R2 score: {model_r2}')
    print(f'Train RMSE: {model_rmse_train}')
    print(f'Test RMSE: {model_rmse_test}')
    print(f'Bad Weather RMSE: {model_rmse_bad_weather}')
    print()
# Out:
# --------- Results for model: Linear Regression ---------
# Test R2 score: 0.8309008899812911
# Train RMSE: 812.0112044587564
# Test RMSE: 812.1924294039009
# Bad Weather RMSE: 866.6172524507979
#
# --------- Results for model: Decision Tree ---------
# Test R2 score: 0.9374785344749575
# Train RMSE: 464.8493369919377
# Test RMSE: 493.85886143924614
# Bad Weather RMSE: 553.0460217545879
#
# --------- Results for model: Random Forest ---------
# Test R2 score: 0.9356372355207904
# Train RMSE: 499.97885234372706
# Test RMSE: 501.0783294025616
# Bad Weather RMSE: 551.7639402317704
#
# --------- Results for model: Bagging ---------
# Test R2 score: 0.9369329117745895
# Train RMSE: 493.5691894734022
# Test RMSE: 496.0091250430742
# Bad Weather RMSE: 543.8492289934487
#
# --------- Results for model: xGBoost ---------
# Test R2 score: 0.946966869750264
# Train RMSE: 375.4736179267677
# Test RMSE: 454.8434102154836
# Bad Weather RMSE: 517.9421639903525

# %%
import os
os.makedirs('Results', exist_ok=True)

no_weather_results = pd.DataFrame({
    'model': model_used,
    'r2': r2,
    'train_rmse': RMSE_train,
    'test_rmse': RMSE_test,
    'bad_weather_rmse': RMSE_bad_weather
})

no_weather_results.to_csv(r'Results/results_weather_none.csv', index=False)
print(no_weather_results)
# Out:
#                model        r2  train_rmse   test_rmse  bad_weather_rmse
# 0  Linear Regression  0.830901  812.011204  812.192429        866.617252
# 1      Decision Tree  0.937479  464.849337  493.858861        553.046022
# 2      Random Forest  0.935637  499.978852  501.078329        551.763940
# 3            Bagging  0.936933  493.569189  496.009125        543.849229
# 4            xGBoost  0.946967  375.473618  454.843410        517.942164

# %% [markdown]
# ## 4.3 Apply Models (weather_main)

# %%
model_used = []
r2 = []
RMSE_train = []
RMSE_test = []
RMSE_bad_weather = []

main_preds = {}

rows = int(len(X_main.index) * 3/10)

X_train_main = X_main[:-rows]
X_test_main  = X_main[-rows:]

y_train_main = y_main[:-rows]
y_test_main  = y_main[-rows:]

bad_weather_test = bad_weather[-rows:]

for name, model in models.items():
    model.fit(X_train_main, y_train_main)
    y_train_pred = model.predict(X_train_main)
    y_test_pred  = model.predict(X_test_main)

    model_r2            = r2_score(y_test_main, y_test_pred)
    model_rmse_train    = np.sqrt(mean_squared_error(y_train_main, y_train_pred))
    model_rmse_test     = np.sqrt(mean_squared_error(y_test_main, y_test_pred))

    y_bad_weather      = y_test_main[bad_weather_test]
    y_bad_weather_pred = y_test_pred[bad_weather_test]
    model_rmse_bad_weather = np.sqrt(mean_squared_error(y_bad_weather, y_bad_weather_pred))

    main_preds[name] = {
        'y_train':      y_train_main,
        'y_train_pred': y_train_pred,
        'y_test':       y_test_main,
        'y_test_pred':  y_test_pred,
        'y_bad_weather':      y_bad_weather,
        'y_bad_weather_pred': y_bad_weather_pred,
    }

    model_used.append(name)
    r2.append(model_r2)
    RMSE_train.append(model_rmse_train)
    RMSE_test.append(model_rmse_test)
    RMSE_bad_weather.append(model_rmse_bad_weather)

    print(f'--------- Results for model: {name} ---------')
    print(f'Test R2 score: {model_r2}')
    print(f'Train RMSE: {model_rmse_train}')
    print(f'Test RMSE: {model_rmse_test}')
    print(f'Bad Weather RMSE: {model_rmse_bad_weather}')
    print()
# Out:
# --------- Results for model: Linear Regression ---------
# Test R2 score: 0.8318081978612163
# Train RMSE: 810.6797417977913
# Test RMSE: 810.0105736570708
# Bad Weather RMSE: 864.8792620163002
#
# --------- Results for model: Decision Tree ---------
# Test R2 score: 0.9374761577455919
# Train RMSE: 464.8176811491133
# Test RMSE: 493.8682482769804
# Bad Weather RMSE: 552.9694768826931
#
# --------- Results for model: Random Forest ---------
# Test R2 score: 0.9335487506135558
# Train RMSE: 507.2421316117553
# Test RMSE: 509.1430870697638
# Bad Weather RMSE: 559.8814602547648
#
# --------- Results for model: Bagging ---------
# Test R2 score: 0.9361236931019427
# Train RMSE: 496.7414622106838
# Test RMSE: 499.1811480243005
# Bad Weather RMSE: 545.2942446314871
#
# --------- Results for model: xGBoost ---------
# Test R2 score: 0.9461396054026413
# Train RMSE: 380.0878759875934
# Test RMSE: 458.3772360283112
# Bad Weather RMSE: 520.3867667837817

# %%
weather_main_results = pd.DataFrame({
    'model': model_used,
    'r2': r2,
    'train_rmse': RMSE_train,
    'test_rmse': RMSE_test,
    'bad_weather_rmse': RMSE_bad_weather
})

weather_main_results.to_csv(r'Results/results_weather_main.csv', index=False)
print(weather_main_results)
# Out:
#                model        r2  train_rmse   test_rmse  bad_weather_rmse
# 0  Linear Regression  0.831808  810.679742  810.010574        864.879262
# 1      Decision Tree  0.937476  464.817681  493.868248        552.969477
# 2      Random Forest  0.933549  507.242132  509.143087        559.881460
# 3            Bagging  0.936124  496.741462  499.181148        545.294245
# 4            xGBoost  0.946140  380.087876  458.377236        520.386767

# %% [markdown]
# ## 4.4 Apply Models (weather_description)

# %%
model_used = []
r2 = []
RMSE_train = []
RMSE_test = []
RMSE_bad_weather = []

desc_preds = {}

rows = int(len(X_desc.index) * 3/10)

X_train_desc = X_desc[:-rows]
X_test_desc  = X_desc[-rows:]

y_train_desc = y_desc[:-rows]
y_test_desc  = y_desc[-rows:]

bad_weather_test = bad_weather[-rows:]

for name, model in models.items():
    model.fit(X_train_desc, y_train_desc)
    y_train_pred = model.predict(X_train_desc)
    y_test_pred  = model.predict(X_test_desc)

    model_r2            = r2_score(y_test_desc, y_test_pred)
    model_rmse_train    = np.sqrt(mean_squared_error(y_train_desc, y_train_pred))
    model_rmse_test     = np.sqrt(mean_squared_error(y_test_desc, y_test_pred))

    y_bad_weather      = y_test_desc[bad_weather_test]
    y_bad_weather_pred = y_test_pred[bad_weather_test]
    model_rmse_bad_weather = np.sqrt(mean_squared_error(y_bad_weather, y_bad_weather_pred))

    desc_preds[name] = {
        'y_train':      y_train_desc,
        'y_train_pred': y_train_pred,
        'y_test':       y_test_desc,
        'y_test_pred':  y_test_pred,
        'y_bad_weather':      y_bad_weather,
        'y_bad_weather_pred': y_bad_weather_pred,
    }

    model_used.append(name)
    r2.append(model_r2)
    RMSE_train.append(model_rmse_train)
    RMSE_test.append(model_rmse_test)
    RMSE_bad_weather.append(model_rmse_bad_weather)

    print(f'--------- Results for model: {name} ---------')
    print(f'Test R2 score: {model_r2}')
    print(f'Train RMSE: {model_rmse_train}')
    print(f'Test RMSE: {model_rmse_test}')
    print(f'Bad Weather RMSE: {model_rmse_bad_weather}')
    print()
# Out:
# --------- Results for model: Linear Regression ---------
# Test R2 score: 0.8317904472608578
# Train RMSE: 809.4870635290076
# Test RMSE: 810.0533159145887
# Bad Weather RMSE: 864.7892039271022
#
# --------- Results for model: Decision Tree ---------
# Test R2 score: 0.9374493145013867
# Train RMSE: 464.83888610826733
# Test RMSE: 493.9742526660068
# Bad Weather RMSE: 553.1062082761949
#
# --------- Results for model: Random Forest ---------
# Test R2 score: 0.9232418999721075
# Train RMSE: 547.6758116705121
# Test RMSE: 547.2054122402244
# Bad Weather RMSE: 591.168771542718
#
# --------- Results for model: Bagging ---------
# Test R2 score: 0.9358893193866463
# Train RMSE: 498.06619224581823
# Test RMSE: 500.096102437642
# Bad Weather RMSE: 545.3528203996243
#
# --------- Results for model: xGBoost ---------
# Test R2 score: 0.9480920979189004
# Train RMSE: 374.8117932836239
# Test RMSE: 449.99222954101765
# Bad Weather RMSE: 511.88612861937077

# %%
weather_desc_results = pd.DataFrame({
    'model': model_used,
    'r2': r2,
    'train_rmse': RMSE_train,
    'test_rmse': RMSE_test,
    'bad_weather_rmse': RMSE_bad_weather
})

weather_desc_results.to_csv(r'Results/results_weather_desc.csv', index=False)
print(weather_desc_results)
# Out:
#                model        r2  train_rmse   test_rmse  bad_weather_rmse
# 0  Linear Regression  0.831790  809.487064  810.053316        864.789204
# 1      Decision Tree  0.937449  464.838886  493.974253        553.106208
# 2      Random Forest  0.923242  547.675812  547.205412        591.168772
# 3            Bagging  0.935889  498.066192  500.096102        545.352820
# 4            xGBoost  0.948092  374.811793  449.992230        511.886129

# %% [markdown]
# # 5. Modelling on ERA5 Climate Data
#
# Features used:
# - Qualitative: Hour of day, Day of the week, Month of year (harmonic encoding), Holidays, and Precipitation type (ERA5, separated by a 0.1 mm threshold)
# - Quantitative: Temperature (ERA5)
#
# The 0.1 mm threshold separates lighter and heavier precipitation with reasonable proportions (see EDA). It is a hyperparameter.
#
# Bad weather conditions follow the same definition as in the traffic dataframe, for consistency.
# ## 5.1 One-Hot Encoding for ERA5 Precipitation Type (with Threshold)

# %%
# Create temporary dataframe that includes precipitation threshold
threshold = 0.1

dummy_weaERA5 = ERA5[['ptype', 'tp']].copy()

dummy_weaERA5['ptype'] = dummy_weaERA5.apply(
    lambda row: str(row['ptype']) + '_light' if row['tp'] > threshold
    else str(row['ptype']) + '_heavy',
    axis=1
)

# Final one hot encoding
dummy_weaERA5 = pd.get_dummies(dummy_weaERA5['ptype'])
dummy_weaERA5.head()
# Out:
#    Freezing rain_heavy  Freezing rain_light  Ice pellets_heavy  \
# 0                False                False              False
# 1                False                False              False
# 2                False                False              False
# 3                False                False              False
# 4                False                False              False
#
#    Ice pellets_light  Rain-snow mix_heavy  Rain-snow mix_light  Rain_heavy  \
# 0              False                False                False       False
# 1              False                False                False       False
# 2              False                False                False       False
# 3              False                False                False       False
# 4              False                False                False       False
#
#    Rain_light  Snow_heavy  Snow_light  Wet snow_heavy  Wet snow_light  \
# 0       False       False       False           False           False
# 1       False       False       False           False           False
# 2       False       False       False           False           False
# 3       False       False       False           False           False
# 4       False       False       False           False           False
#
#    nan_heavy  nan_light
# 0       True      False
# 1       True      False
# 2       True      False
# 3       True      False
# 4       True      False

# %% [markdown]
# ## 5.2 Build Feature Set

# %%
# Create dataframe appropriate for training
X_ERA5 = pd.concat([traffic.temp, dummy_seasonalities, dummy_holiday, dummy_weaERA5],
                   axis=1)
y_ERA5 = traffic.traffic_volume

print(f'X_ERA5 shape: {X_ERA5.shape}')
X_ERA5.head()
# Out:
# X_ERA5 shape: (48176, 56)
#      temp    hour_sin_1  hour_cos_1    hour_sin_2    hour_cos_2    hour_sin_3  \
# 0  288.28  7.071068e-01   -0.707107 -1.000000e+00 -1.836970e-16  7.071068e-01
# 1  289.36  5.000000e-01   -0.866025 -8.660254e-01  5.000000e-01  1.000000e+00
# 2  289.58  2.588190e-01   -0.965926 -5.000000e-01  8.660254e-01  7.071068e-01
# 3  290.13  1.224647e-16   -1.000000 -2.449294e-16  1.000000e+00  3.673940e-16
# 4  291.14 -2.588190e-01   -0.965926  5.000000e-01  8.660254e-01 -7.071068e-01
#
#      hour_cos_3    hour_sin_4  hour_cos_4    hour_sin_5  ...  \
# 0  7.071068e-01  3.673940e-16        -1.0 -7.071068e-01  ...
# 1  1.194340e-15 -8.660254e-01        -0.5  5.000000e-01  ...
# 2 -7.071068e-01 -8.660254e-01         0.5  9.659258e-01  ...
# 3 -1.000000e+00 -4.898587e-16         1.0  2.388680e-15  ...
# 4 -7.071068e-01  8.660254e-01         0.5 -9.659258e-01  ...
#
#    Rain-snow mix_heavy  Rain-snow mix_light  Rain_heavy  Rain_light  \
# 0                False                False       False       False
# 1                False                False       False       False
# 2                False                False       False       False
# 3                False                False       False       False
# 4                False                False       False       False
#
#    Snow_heavy  Snow_light  Wet snow_heavy  Wet snow_light  nan_heavy  \
# 0       False       False           False           False       True
# 1       False       False           False           False       True
# 2       False       False           False           False       True
# 3       False       False           False           False       True
# 4       False       False           False           False       True
#
#    nan_light
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#
# [5 rows x 56 columns]

# %% [markdown]
# ## 5.3 Apply Models

# %%
model_used = []
r2 = []
RMSE_train = []
RMSE_test = []
RMSE_bad_weather = []

ERA5_preds = {}

rows = int(len(X_ERA5.index) * 3/10)

X_train_ERA5 = X_ERA5[:-rows]
X_test_ERA5  = X_ERA5[-rows:]

y_train_ERA5 = y_ERA5[:-rows]
y_test_ERA5  = y_ERA5[-rows:]

bad_weather_test = bad_weather[-rows:]

for name, model in models.items():
    model.fit(X_train_ERA5, y_train_ERA5)
    y_train_pred = model.predict(X_train_ERA5)
    y_test_pred  = model.predict(X_test_ERA5)

    model_r2            = r2_score(y_test_ERA5, y_test_pred)
    model_rmse_train    = np.sqrt(mean_squared_error(y_train_ERA5, y_train_pred))
    model_rmse_test     = np.sqrt(mean_squared_error(y_test_ERA5, y_test_pred))

    y_bad_weather      = y_test_ERA5[bad_weather_test]
    y_bad_weather_pred = y_test_pred[bad_weather_test]
    model_rmse_bad_weather = np.sqrt(mean_squared_error(y_bad_weather, y_bad_weather_pred))

    ERA5_preds[name] = {
        'y_train':      y_train_ERA5,
        'y_train_pred': y_train_pred,
        'y_test':       y_test_ERA5,
        'y_test_pred':  y_test_pred,
        'y_bad_weather':      y_bad_weather,
        'y_bad_weather_pred': y_bad_weather_pred,
    }

    model_used.append(name)
    r2.append(model_r2)
    RMSE_train.append(model_rmse_train)
    RMSE_test.append(model_rmse_test)
    RMSE_bad_weather.append(model_rmse_bad_weather)

    print(f'--------- Results for model: {name} ---------')
    print(f'Test R2 score: {model_r2}')
    print(f'Train RMSE: {model_rmse_train}')
    print(f'Test RMSE: {model_rmse_test}')
    print(f'Bad Weather RMSE: {model_rmse_bad_weather}')
    print()
# Out:
# --------- Results for model: Linear Regression ---------
# Test R2 score: 0.8365826897452304
# Train RMSE: 804.2266065481527
# Test RMSE: 798.4308428313956
# Bad Weather RMSE: 840.5590801635688
#
# --------- Results for model: Decision Tree ---------
# Test R2 score: 0.9400760634488647
# Train RMSE: 463.6305010381268
# Test RMSE: 483.49105519324127
# Bad Weather RMSE: 529.2849665287575
#
# --------- Results for model: Random Forest ---------
# Test R2 score: 0.9349974230193409
# Train RMSE: 505.2998846186877
# Test RMSE: 503.56271131213197
# Bad Weather RMSE: 550.2457307082758
#
# --------- Results for model: Bagging ---------
# Test R2 score: 0.9366604891266171
# Train RMSE: 495.5582498106721
# Test RMSE: 497.07924353017484
# Bad Weather RMSE: 541.2036264807668
#
# --------- Results for model: xGBoost ---------
# Test R2 score: 0.9520277223979516
# Train RMSE: 362.1920247917903
# Test RMSE: 432.596942057394
# Bad Weather RMSE: 476.0914266967721

# %%
weather_ERA5_results = pd.DataFrame({
    'model': model_used,
    'r2': r2,
    'train_rmse': RMSE_train,
    'test_rmse': RMSE_test,
    'bad_weather_rmse': RMSE_bad_weather
})

weather_ERA5_results.to_csv(r'Results/results_ERA5.csv', index=False)
print(weather_ERA5_results)
# Out:
#                model        r2  train_rmse   test_rmse  bad_weather_rmse
# 0  Linear Regression  0.836583  804.226607  798.430843        840.559080
# 1      Decision Tree  0.940076  463.630501  483.491055        529.284967
# 2      Random Forest  0.934997  505.299885  503.562711        550.245731
# 3            Bagging  0.936660  495.558250  497.079244        541.203626
# 4            xGBoost  0.952028  362.192025  432.596942        476.091427

# %% [markdown]
# # 6. Compare Evaluations Across Approaches
# ## 6.1 Load Results

# %%
# Read result csvs
evaluation_none = pd.read_csv(r'Results/results_weather_none.csv')
evaluation_main = pd.read_csv(r'Results/results_weather_main.csv')
evaluation_desc = pd.read_csv(r'Results/results_weather_desc.csv')
evaluation_ERA5 = pd.read_csv(r'Results/results_ERA5.csv')

evaluation_ERA5
# Out:
#                model        r2  train_rmse   test_rmse  bad_weather_rmse
# 0  Linear Regression  0.836583  804.226607  798.430843        840.559080
# 1      Decision Tree  0.940076  463.630501  483.491055        529.284967
# 2      Random Forest  0.934997  505.299885  503.562711        550.245731
# 3            Bagging  0.936660  495.558250  497.079244        541.203626
# 4            xGBoost  0.952028  362.192025  432.596942        476.091427

# %%
# Add a new column for each dataframe saying where the source is
evaluation_none['Approach'] = 'No weather data'
evaluation_main['Approach'] = 'Main weather data'
evaluation_desc['Approach'] = 'Descriptive weather data'
evaluation_ERA5['Approach'] = 'ERA5 weather data'

# Merge dataframes into one
evaluation = pd.concat([evaluation_none, evaluation_main, evaluation_desc, evaluation_ERA5], ignore_index=False)
evaluation.reset_index(drop=True, inplace=True)

del evaluation_none, evaluation_main, evaluation_desc, evaluation_ERA5

evaluation.head()
# Out:
#                model        r2  train_rmse   test_rmse  bad_weather_rmse  \
# 0  Linear Regression  0.830901  812.011204  812.192429        866.617252
# 1      Decision Tree  0.937479  464.849337  493.858861        553.046022
# 2      Random Forest  0.935637  499.978852  501.078329        551.763940
# 3            Bagging  0.936933  493.569189  496.009125        543.849229
# 4            xGBoost  0.946967  375.473618  454.843410        517.942164
#
#           Approach
# 0  No weather data
# 1  No weather data
# 2  No weather data
# 3  No weather data
# 4  No weather data

# %% [markdown]
# ## 6.2 Bar Plots by Regression Method and Weather Data Approach

# %%
fig, axes = plt.subplots(5, 2, figsize=(16, 20), gridspec_kw={'width_ratios': [3, 1]})

bar_colors = ['steelblue', 'darkorange', 'tomato']
approaches = evaluation['Approach'].unique()
short_labels = ['No wea.', 'Main wea.', 'Desc wea.', 'ERA5 wea.']
model_names = list(models.keys())

x = np.arange(len(approaches))
width = 0.25

for row_idx, model_name in enumerate(model_names):
    ax_rmse = axes[row_idx, 0]
    ax_r2   = axes[row_idx, 1]

    subset = evaluation[evaluation['model'] == model_name]
    subset = subset.set_index('Approach').reindex(approaches)

    # RMSE bars
    bars = [
        ax_rmse.bar(x - width, subset['train_rmse'],       width, label='Train RMSE',       color=bar_colors[0]),
        ax_rmse.bar(x,         subset['test_rmse'],        width, label='Test RMSE',        color=bar_colors[1]),
        ax_rmse.bar(x + width, subset['bad_weather_rmse'], width, label='Bad weather RMSE', color=bar_colors[2]),
    ]
    for bar_group in bars:
        for p in bar_group:
            ax_rmse.annotate(f'{p.get_height():.1f}',
                             (p.get_x() + p.get_width() / 2., p.get_height()),
                             ha='center', va='bottom', fontsize=7.5, xytext=(0, 3),
                             textcoords='offset points')
    ax_rmse.set_title(model_name, fontsize=13, fontweight='bold')
    ax_rmse.set_xticks(x)
    ax_rmse.set_xticklabels(short_labels, fontsize=10)
    ax_rmse.set_ylabel('RMSE', fontsize=11)
    ax_rmse.set_ylim(0, 900)
    ax_rmse.legend(fontsize=9, loc='lower right')

    # R2 bars
    bar_r2 = ax_r2.bar(x, subset['r2'], width * 2, color='mediumpurple')
    for p in bar_r2:
        ax_r2.annotate(f'{p.get_height():.3f}',
                       (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='bottom', fontsize=7.5, xytext=(0, 3),
                       textcoords='offset points')
    ax_r2.set_title('R2', fontsize=13, fontweight='bold')
    ax_r2.set_xticks(x)
    ax_r2.set_xticklabels(short_labels, fontsize=10)
    ax_r2.set_ylabel('R2 Score', fontsize=11)
    ax_r2.set_ylim(0.8, 1.0)

plt.suptitle('RMSE and R2 by model and feature set\n', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.savefig('rmse_r2_by_model.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6.3 Real data vs Predicted data
#
# Each subplot shows three scatter layers:
# - Training set (actual vs predicted)
# - Test set (actual vs predicted)
# - Test set, bad weather rows only (actual vs predicted)
#
# The solid red line is y = x (perfect prediction). Dashed red lines are +/- test RMSE.

# %%
feature_sets = {
    'No weather':          none_preds,
    'Main weather':        main_preds,
    'Descriptive weather': desc_preds,
    'ERA5 weather':        ERA5_preds,
}

train_color = 'black'
test_colors = ['steelblue', 'darkorange', 'forestgreen', 'mediumpurple']

model_names = list(models.keys())

fig, axes = plt.subplots(4, 5, figsize=(15 * 1.3, 12 * 1.3), sharex=True, sharey=True)

for row_idx, (feat_name, preds_dict) in enumerate(feature_sets.items()):
    test_color = test_colors[row_idx]

    for col_idx, model_name in enumerate(model_names):
        ax = axes[row_idx, col_idx]

        p = preds_dict[model_name]

        y_train      = np.array(p['y_train'])
        y_train_pred = np.array(p['y_train_pred'])
        y_test       = np.array(p['y_test'])
        y_test_pred  = np.array(p['y_test_pred'])

        rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

        lims = [
            min(y_train.min(), y_test.min(), y_train_pred.min(), y_test_pred.min()),
            max(y_train.max(), y_test.max(), y_train_pred.max(), y_test_pred.max())
        ]

        # Training scatter
        ax.scatter(
            y_train, y_train_pred,
            alpha=0.1, s=3,
            color=train_color,
            label='Train'
        )

        # Test scatter
        ax.scatter(
            y_test, y_test_pred,
            alpha=0.2, s=3,
            color=test_color,
            label='Test'
        )

        # Reference lines
        ax.plot(lims, lims, color='red', linewidth=1.5)
        ax.plot(
            lims, [l + rmse_test for l in lims],
            color='red', linewidth=1.2, linestyle='--',
            label=f'±RMSE ({rmse_test:.0f})'
        )
        ax.plot(
            lims, [l - rmse_test for l in lims],
            color='red', linewidth=1.2, linestyle='--'
        )
        lim = (0, 7500)
        ax.set_xlim(lim)
        ax.set_ylim(lim)
        
        ax.legend(fontsize=8, loc='upper left', markerscale=1.5)
        ax.tick_params(labelsize=10)

        if row_idx == 0:
            ax.set_title(model_name, fontsize=13, fontweight='bold', pad=10)

        if col_idx == 0:
            feat_name_camel = ''.join(word.capitalize() for word in feat_name.split())
            ax.set_ylabel(
                rf'$\bf{{{feat_name_camel}}}$' + '\nPredicted',
                fontsize=12
            )

        if row_idx == 3:
            ax.set_xlabel('Actual', fontsize=12)
            
plt.suptitle(
    'Actual vs Predicted traffic volume per model and feature set',
    fontsize=15,
    fontweight='bold',
    y=1.00
)

plt.tight_layout()
plt.savefig('actual_vs_predicted.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# A/B Testing: Statistical Significance of All Weather Datasets vs No Weather for XGBoost
from scipy import stats

# Extract XGBoost predictions for all approaches
xgb_none = none_preds['xGBoost']
xgb_main = main_preds['xGBoost']
xgb_desc = desc_preds['xGBoost']
xgb_era5 = ERA5_preds['xGBoost']

# Baseline: No Weather bad weather residuals
y_true_baseline = xgb_none['y_bad_weather']
y_pred_baseline = xgb_none['y_bad_weather_pred']
residuals_baseline = (y_true_baseline - y_pred_baseline) ** 2
rmse_baseline = np.sqrt(np.mean(residuals_baseline))

# Dictionary of approaches to test
approaches = {
    'Main Weather': xgb_main,
    'Descriptive Weather': xgb_desc,
    'ERA5 Weather': xgb_era5
}

print("XGBoost Bad Weather RMSE: No Weather vs All Approaches\n")
print(f"{'Baseline (No Weather):':.<40} {rmse_baseline:.2f}\n")

results = []

for approach_name, xgb_data in approaches.items():
    y_true = xgb_data['y_bad_weather']
    y_pred = xgb_data['y_bad_weather_pred']
    residuals = (y_true - y_pred) ** 2
    rmse = np.sqrt(np.mean(residuals))
    
    # Paired t-test
    t_stat, p_value = stats.ttest_rel(residuals_baseline, residuals)
    
    improvement = rmse_baseline - rmse
    pct_improvement = (improvement / rmse_baseline) * 100
    
    print(f"{approach_name}:")
    print(f"  RMSE:         {rmse:.2f}")
    print(f"  Difference:   {improvement:.2f} ({pct_improvement:+.1f}%)")
    print(f"  t-statistic:  {t_stat:.4f}")
    print(f"  p-value:      {p_value:.6f}")
    print(f"  Significant:  {'Yes' if p_value < 0.05 else 'No'} (alpha=0.05)")
    
    if p_value < 0.05:
        better = 'Better than' if rmse < rmse_baseline else 'Worse than'
        print(f"  Conclusion:   {better} baseline (p={p_value:.4f})")
    else:
        print(f"  Conclusion:   No significant difference (p={p_value:.4f})")
    
    print()
    results.append({
        'Approach': approach_name,
        'RMSE': rmse,
        't_stat': t_stat,
        'p_value': p_value,
        'Significant': p_value < 0.05
    })

# Summary table
results_df = pd.DataFrame(results)
results_df = results_df.sort_values('p_value')
print("Summary (sorted by p-value):")
print(results_df.to_string(index=False))
# Out:
# XGBoost Bad Weather RMSE: No Weather vs All Approaches
#
# Baseline (No Weather):.................. 517.94
#
# Main Weather:
#   RMSE:         520.39
#   Difference:   -2.44 (-0.5%)
#   t-statistic:  -1.1546
#   p-value:      0.248298
#   Significant:  No (alpha=0.05)
#   Conclusion:   No significant difference (p=0.2483)
#
# Descriptive Weather:
#   RMSE:         511.89
#   Difference:   6.06 (+1.2%)
#   t-statistic:  2.4871
#   p-value:      0.012905
#   Significant:  Yes (alpha=0.05)
#   Conclusion:   Better than baseline (p=0.0129)
#
# ERA5 Weather:
#   RMSE:         476.09
#   Difference:   41.85 (+8.1%)
#   t-statistic:  10.2491
#   p-value:      0.000000
#   Significant:  Yes (alpha=0.05)
#   Conclusion:   Better than baseline (p=0.0000)
#
# Summary (sorted by p-value):
#            Approach       RMSE    t_stat      p_value  Significant
#        ERA5 Weather 476.091427 10.249081 1.851231e-24         True
# Descriptive Weather 511.886129  2.487088 1.290484e-02         True
#        Main Weather 520.386767 -1.154599 2.482981e-01        False
